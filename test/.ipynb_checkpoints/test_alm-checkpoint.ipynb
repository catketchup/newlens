# %%
from healpy import sphtfunc
import healpy
import numpy as np
import matplotlib.pyplot as plt
import path

# %%
input_cl = np.arange(1,1000)
input_map = sphtfunc.synfast(input_cl, 350)
healpy.visufunc.mollview(input_map)
input_alm = sphtfunc.map2alm(input_map)
print(input_alm)
output_cl = sphtfunc.alm2cl(input_alm)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# [ 6.43654081e-01+0.00000000e+00j  7.05755111e-01+0.00000000e+00j
#   1.58475361e+00+0.00000000e+00j ... -1.36080383e-14-5.62440719e-15j
#   7.64362532e-15-1.79266324e-14j  4.16073426e-15+4.87023616e-16j]

# %%
plt.plot(input_cl)
plt.plot(output_cl)
plt.show()
