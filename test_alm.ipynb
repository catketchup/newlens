# %%
from healpy import sphtfunc
import healpy
import numpy as np
import matplotlib.pyplot as plt
import path
import load_data

import noise_model

# %%
lmin = 1
lmax = 1000
# healpy.visufunc.mollview(input_map) # plot the map
# plt.show()

# %%
#input_cl = np.arange(1,1000) # input power spectrum
input_cl1 = load_data.lensed(lmin, lmax, 'TT').spectra()
input_map1 = sphtfunc.synfast(input_cl1, 320, fwhm=0.0) # create a map using input power spectrum
almfmap1 = sphtfunc.map2alm(input_map1) # get alm from the map
clfmap1 = sphtfunc.alm2cl(almfmap1) # get clm using the alm got from the map
plt.plot(input_cl)
plt.plot(clfmap)
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
input_cl2 = np.arange(lmin, lmax)
input_map2 = sphtfunc.synfast(input_cl2, 320)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
input_map = input_map1 * input_map2

# %%
almfmap = sphtfunc.map2alm(input_map2)
clfmap = sphtfunc.alm2cl(almfmap)
plt.plot(clfmap)
plt.plot()
# Out:
# []

# %%
def ret(a):
    return a+1,a+2

A, B = ret(1)
print(A, B)
# Out:
# 2 3
